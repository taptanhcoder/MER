# %%
import os, sys, platform, torch, numpy as np

print("CWD:", os.getcwd())
print("Python:", platform.python_version())
print("Torch:", torch.__version__, "| CUDA available:", torch.cuda.is_available())
# Out:
# CWD: /mnt/d/MER/src
# Python: 3.12.3
# Torch: 2.7.1+cu126 | CUDA available: True

# %%
from configs.base import Config

import importlib
import loading.dataloader as data_loader
importlib.reload(data_loader) 

from model.networks import MER 
from model.losses import CrossEntropyLoss

from training.trainer import TorchTrainer
from training.callbacks import CheckpointsCallback
from training.optimizers import split_param_groups, build_optimizer
# Out:
# 2025-08-22 14:57:18.320741: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1755874639.637987  158299 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1755874639.987095  158299 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1755874643.107186  158299 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755874643.107215  158299 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755874643.107217  158299 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755874643.107218  158299 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-08-22 14:57:23.410106: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
from pathlib import Path

cfg = Config(
    name="MER_VNEMOS_PhoBERT_W2V2_A_lengthbucket",
    checkpoint_dir="../checkpoints/mer_vnemos_A",
    num_epochs=2,
    batch_size=8,
    learning_rate=2e-5,
    optimizer_type="AdamW",
    save_best_val=True,
    max_to_keep=2,
    num_workers=2,

    # Data
    data_root="../output",
    jsonl_dir="",
    sample_rate=16000,
    max_audio_sec=None,      
    text_max_length=64,

    # Sampler theo độ dài (Phương án A)
    use_length_bucket=True,   
    length_bucket_size=64,

    # Model
    model_type="MemoCMT",
    text_encoder_type="phobert",
    text_encoder_ckpt="vinai/phobert-base",
    text_encoder_dim=768,
    text_unfreeze=False,

    audio_encoder_type="wav2vec2_xlsr",
    audio_encoder_ckpt="facebook/wav2vec2-large-xlsr-53",
    audio_encoder_dim=1024,
    audio_unfreeze=False,

    fusion_dim=768,
    fusion_head_output_type="mean",
    linear_layer_output=[128],

    use_amp=True,
    max_grad_norm=1.0,
)

base_dir = (Path(cfg.data_root) / (cfg.jsonl_dir or "")).resolve()
audio_root_print = Path(getattr(cfg, "audio_root", "") or base_dir.parent).resolve()
print("base_dir:", base_dir)
print("audio_root (auto):", audio_root_print)
# Out:
# base_dir: /mnt/d/MER/output
# audio_root (auto): /mnt/d/MER

# %%
train_loader, eval_loader = data_loader.build_train_test_dataset(cfg)

train_ds = train_loader.dataset
if hasattr(train_ds, "label2id"):
    cfg.num_classes = len(train_ds.label2id)
    id2label = [k for k, v in sorted(train_ds.label2id.items(), key=lambda x: x[1])]
else:
    cfg.num_classes = 4
    id2label = list(range(cfg.num_classes))

print("Classes:", cfg.num_classes, id2label)
print(f"Train batches: {len(train_loader)} | Eval batches: {len(eval_loader) if eval_loader else 0}")
# Out:
# Classes: 5 ['angry', 'fear', 'happiness', 'neutral', 'sadness']
# Train batches: 25 | Eval batches: 4

# %%
from transformers import BatchEncoding

device = "cuda" if torch.cuda.is_available() else "cpu"
network = MER(cfg, device=device)
criterion = CrossEntropyLoss(cfg)

class MERTrainer(TorchTrainer):
    def __init__(self, cfg, network, criterion, **kwargs):
        super().__init__(**kwargs)
        self.cfg = cfg
        self.network = network
        self.criterion = criterion
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.network.to(self.device)
        self.use_amp = bool(getattr(cfg, "use_amp", torch.cuda.is_available()))
        self.max_grad_norm = float(getattr(cfg, "max_grad_norm", 0.0))
        self.scaler = torch.cuda.amp.GradScaler(enabled=self.use_amp)

    def _to_device_text(self, x):
        if isinstance(x, BatchEncoding):
            x = x.to(self.device)
            return {k: v for k, v in x.items()}
        if isinstance(x, dict):
            return {k: v.to(self.device) for k, v in x.items()}
        return x.to(self.device)

    def _standardize_batch(self, batch):

        # ((tok,a,l), meta)
        if isinstance(batch, (tuple, list)) and len(batch) == 2:
            a, meta = batch
            if isinstance(a, (tuple, list)) and len(a) == 3:
                tok, audio, labels = a
                return tok, audio, labels, meta
            if isinstance(a, (dict, BatchEncoding)) and isinstance(meta, (tuple, list)) and len(meta) == 2:
                # dạng ít gặp: (tok, (audio, labels))
                tok = a
                audio, labels = meta
                return tok, audio, labels, None

        # (tok,a,l)
        if isinstance(batch, (tuple, list)) and len(batch) == 3:
            tok, audio, labels = batch
            return tok, audio, labels, None

        # dict
        if isinstance(batch, dict):
            tok = batch.get("text"); audio = batch.get("audio"); labels = batch.get("label")
            if tok is not None and audio is not None and labels is not None:
                return tok, audio, labels, None

        raise ValueError(f"Batch structure không hỗ trợ: preview={str(batch)[:200]}")

    def train_step(self, batch):
        self.network.train()
        self.optimizer.zero_grad(set_to_none=True)

        input_text, input_audio, labels, meta = self._standardize_batch(batch)
        input_audio = input_audio.to(self.device, non_blocking=True)
        labels = labels.to(self.device, non_blocking=True)
        input_text = self._to_device_text(input_text)

        if self.use_amp:
            with torch.cuda.amp.autocast():
                # >>> TRUYỀN meta để bật audio mask theo Phương án A
                out = self.network(input_text, input_audio, meta=meta)
                logits = out[0] if isinstance(out, (tuple, list)) else out
                loss = self.criterion(out, labels) if isinstance(out, (tuple, list)) else self.criterion(logits, labels)
            self.scaler.scale(loss).backward()
            if self.max_grad_norm and self.max_grad_norm > 0:
                self.scaler.unscale_(self.optimizer)
                torch.nn.utils.clip_grad_norm_(self.network.parameters(), self.max_grad_norm)
            self.scaler.step(self.optimizer)
            self.scaler.update()
        else:
            out = self.network(input_text, input_audio, meta=meta)  # <<< pass meta
            logits = out[0] if isinstance(out, (tuple, list)) else out
            loss = self.criterion(out, labels) if isinstance(out, (tuple, list)) else self.criterion(logits, labels)
            loss.backward()
            if self.max_grad_norm and self.max_grad_norm > 0:
                torch.nn.utils.clip_grad_norm_(self.network.parameters(), self.max_grad_norm)
            self.optimizer.step()

        preds = torch.argmax(logits, dim=1)
        acc = (preds == labels).float().mean()
        return {"loss": float(loss.detach().cpu()), "acc": float(acc.detach().cpu())}

    def test_step(self, batch):
        self.network.eval()
        input_text, input_audio, labels, meta = self._standardize_batch(batch)
        input_audio = input_audio.to(self.device, non_blocking=True)
        labels = labels.to(self.device, non_blocking=True)
        input_text = self._to_device_text(input_text)
        with torch.no_grad():
            out = self.network(input_text, input_audio, meta=meta)  
            logits = out[0] if isinstance(out, (tuple, list)) else out
            loss = self.criterion(out, labels) if isinstance(out, (tuple, list)) else self.criterion(logits, labels)
            preds = torch.argmax(logits, dim=1)
            acc = (preds == labels).float().mean()
        return {"val_loss": float(loss.detach().cpu()), "val_acc": float(acc.detach().cpu())}

trainer = MERTrainer(cfg, network, criterion, log_dir="logs")
print("Trainer ready. Device:", trainer.device)
# Out:
# Trainer ready. Device: cuda
# /tmp/ipykernel_158299/2903860399.py:17: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = torch.cuda.amp.GradScaler(enabled=self.use_amp)

# %%
from torch.optim.lr_scheduler import CosineAnnealingLR

param_groups = split_param_groups(trainer, lr_enc=cfg.learning_rate * 0.25,
                                  lr_head=cfg.learning_rate, weight_decay=0.01)
optimizer = build_optimizer("adamw", param_groups, lr=cfg.learning_rate, weight_decay=0.01)

scheduler = CosineAnnealingLR(optimizer, T_max=max(1, cfg.num_epochs))
trainer.compile(optimizer=optimizer, scheduler=scheduler, lr=cfg.learning_rate, param_groups=None)
print("Param groups:", len(optimizer.param_groups))
# Out:
# Param groups: 1

# %%
ckpt_cb = CheckpointsCallback(cfg.checkpoint_dir, save_freq=200, max_to_keep=2,
                              save_best_val=True, monitor="val_loss", mode="min")
trainer.fit(train_loader, epochs=cfg.num_epochs, eval_data=eval_loader, callbacks=[ckpt_cb])
print("Best checkpoint:", getattr(ckpt_cb, "best_path", ""))
# Out:
# 2025-08-22 14:58:44,911 - root - WARNING - save_best_val=True → cần truyền validation loader vào trainer.fit(). Best theo metric 'val_loss' (min).
# Epoch 1/2
# 2025-08-22 14:58:46,424 - Training - INFO - Epoch 1/2
# Epoch 1:   0%|          | 0/25 [00:00<?, ?it/s]Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# /tmp/ipykernel_158299/2903860399.py:71: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# /mnt/d/MER/tf/lib/python3.12/site-packages/torch/nn/modules/module.py:1762: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `RobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# Epoch 1:   4%|4         | 1/25 [00:11<04:41, 11.73s/it, loss: 1.5385 | acc: 0.5000]Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Epoch 1:   8%|8         | 2/25 [00:12<02:06,  5.51s/it, loss: 1.6606 | acc: 0.1250]Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Epoch 1:  12%|#2        | 3/25 [00:15<01:27,  3.97s/it, loss: 1.6843 | acc: 0.1250]Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Epoch 1:  16%|#6        | 4/25 [00:19<01:25,  4.08s/it, loss: 1.6643 | acc: 0.1250]Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Epoch 1:  20%|##        | 5/25 [00:23<01:26,  4.31s/it, loss: 1.7440 | acc: 0.0000]Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Epoch 1:  24%|##4       | 6/25 [00:29<01:28,  4.68s/it, loss: 1.6049 | acc: 0.3750]Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Epoch 1:  28%|##8       | 7/25 [00:36<01:40,  5.60s/it, loss: 1.7928 | acc: 0.0000]Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Epoch 1:  32%|###2      | 8/25 [01:01<03:17, 11.62s/it, loss: 1.6855 | acc: 0.0000]Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Epoch 1:  36%|###6      | 9/25 [01:06<02:35,  9.71s/it, loss: 1.5018 | acc: 0.5000]Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Epoch 1:  40%|####      | 10/25 [01:12<02:08,  8.57s/it, loss: 1.5741 | acc: 0.1250]Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Epoch 1:  44%|####4     | 11/25 [01:20<01:54,  8.19s/it, loss: 1.5479 | acc: 0.1250]Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Epoch 1:  48%|####8     | 12/25 [01:28<01:47,  8.31s/it, loss: 1.5737 | acc: 0.1250]Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Epoch 1:  52%|#####2    | 13/25 [01:37<01:42,  8.52s/it, loss: 1.5803 | acc: 0.1250]Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Epoch 1:  56%|#####6    | 14/25 [01:51<01:50, 10.08s/it, loss: 1.7417 | acc: 0.0000]Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Epoch 1:  60%|######    | 15/25 [02:07<01:58, 11.86s/it, loss: 1.5508 | acc: 0.3750]Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Epoch 1:  64%|######4   | 16/25 [02:38<02:39, 17.74s/it, loss: 1.6572 | acc: 0.2500]Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Epoch 1:  68%|######8   | 17/25 [02:43<01:50, 13.81s/it, loss: 1.6399 | acc: 0.3750]Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Epoch 1:  72%|#######2  | 18/25 [02:49<01:19, 11.43s/it, loss: 1.6660 | acc: 0.1250]Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Epoch 1:  76%|#######6  | 19/25 [02:56<01:00, 10.10s/it, loss: 1.5972 | acc: 0.2500]Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Epoch 1:  80%|########  | 20/25 [03:04<00:46,  9.39s/it, loss: 1.6237 | acc: 0.2500]Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Epoch 1: 100%|##########| 25/25 [04:26<00:00, 10.66s/it, loss: 1.4972 | acc: 0.3750]
# Epoch 1 - loss: 1.6193
# 2025-08-22 15:03:12,927 - Training - INFO - Epoch 1 - loss: 1.6193
# Epoch 1 - acc: 0.2050
# 2025-08-22 15:03:13,203 - Training - INFO - Epoch 1 - acc: 0.2050
# Performing validation...
# 2025-08-22 15:03:13,511 - Training - INFO - Performing validation...
# Valid:   0%|          | 0/4 [00:00<?, ?it/s]Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Valid: 100%|##########| 4/4 [00:40<00:00, 10.10s/it]
# Validation: val_loss: 1.4841 val_acc: 0.5625
# 2025-08-22 15:03:53,910 - Training - INFO - Validation: val_loss: 1.4841 val_acc: 0.5625
# Improved val_loss from inf to 1.484088. Saving best...
# 2025-08-22 15:03:54,426 - Training - INFO - Improved val_loss from inf to 1.484088. Saving best...
# Epoch 2/2
# 2025-08-22 15:04:06,524 - Training - INFO - Epoch 2/2
# Epoch 2:   0%|          | 0/25 [00:00<?, ?it/s]Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Epoch 2:   4%|4         | 1/25 [00:06<02:35,  6.48s/it, loss: 1.4464 | acc: 0.6250]Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Epoch 2:   8%|8         | 2/25 [00:13<02:38,  6.91s/it, loss: 1.4258 | acc: 0.5000]Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Epoch 2:  12%|#2        | 3/25 [00:21<02:37,  7.16s/it, loss: 1.4742 | acc: 0.3750]Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Epoch 2:  16%|#6        | 4/25 [00:31<02:53,  8.25s/it, loss: 1.5029 | acc: 0.5000]Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Epoch 2:  20%|##        | 5/25 [00:42<03:11,  9.56s/it, loss: 1.5128 | acc: 0.2500]Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Epoch 2:  24%|##4       | 6/25 [00:56<03:25, 10.81s/it, loss: 1.4893 | acc: 0.3750]Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Epoch 2:  28%|##8       | 7/25 [01:15<04:07, 13.74s/it, loss: 1.5535 | acc: 0.3750]Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Epoch 2:  32%|###2      | 8/25 [01:46<05:26, 19.18s/it, loss: 1.5448 | acc: 0.2500]Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Epoch 2:  36%|###6      | 9/25 [01:52<03:59, 14.98s/it, loss: 1.5052 | acc: 0.2500]Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Epoch 2:  40%|####      | 10/25 [01:59<03:09, 12.61s/it, loss: 1.4922 | acc: 0.6250]Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Epoch 2:  44%|####4     | 11/25 [02:07<02:35, 11.14s/it, loss: 1.4888 | acc: 0.5000]Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Epoch 2:  48%|####8     | 12/25 [02:17<02:18, 10.67s/it, loss: 1.4778 | acc: 0.3750]Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Epoch 2:  52%|#####2    | 13/25 [02:28<02:09, 10.76s/it, loss: 1.4924 | acc: 0.2500]Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Epoch 2:  56%|#####6    | 14/25 [02:39<02:00, 10.93s/it, loss: 1.5746 | acc: 0.3750]Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Epoch 2:  60%|######    | 15/25 [02:58<02:13, 13.36s/it, loss: 1.4526 | acc: 0.6250]Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Epoch 2:  64%|######4   | 16/25 [03:28<02:45, 18.44s/it, loss: 1.4604 | acc: 0.5000]Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Epoch 2:  68%|######8   | 17/25 [03:32<01:52, 14.08s/it, loss: 1.5781 | acc: 0.2500]Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Epoch 2:  72%|#######2  | 18/25 [03:38<01:20, 11.52s/it, loss: 1.5679 | acc: 0.2500]Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Epoch 2:  76%|#######6  | 19/25 [03:44<00:59,  9.92s/it, loss: 1.4788 | acc: 0.5000]Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Epoch 2:  80%|########  | 20/25 [03:51<00:45,  9.10s/it, loss: 1.5475 | acc: 0.6250]Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Epoch 2: 100%|##########| 25/25 [05:26<00:00, 13.07s/it, loss: 1.4894 | acc: 0.5000]
# Epoch 2 - loss: 1.5009
# 2025-08-22 15:09:33,379 - Training - INFO - Epoch 2 - loss: 1.5009
# Epoch 2 - acc: 0.4450
# 2025-08-22 15:09:33,642 - Training - INFO - Epoch 2 - acc: 0.4450
# Performing validation...
# 2025-08-22 15:09:33,964 - Training - INFO - Performing validation...
# Valid:   0%|          | 0/4 [00:00<?, ?it/s]Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Valid: 100%|##########| 4/4 [00:38<00:00,  9.56s/it]
# Validation: val_loss: 1.4551 val_acc: 0.5312
# 2025-08-22 15:10:12,198 - Training - INFO - Validation: val_loss: 1.4551 val_acc: 0.5312
# Improved val_loss from 1.484088 to 1.455109. Saving best...
# 2025-08-22 15:10:12,764 - Training - INFO - Improved val_loss from 1.484088 to 1.455109. Saving best...
# Best checkpoint: ../checkpoints/mer_vnemos_A/best_val_loss/checkpoint_0.pth
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.
# Keyword arguments {'add_prefix_space': True} not recognized.

# %%
import torch
import numpy as np

def collect_preds(trainer, loader):
    all_preds, all_labels = [], []
    trainer.network.eval()
    with torch.no_grad():
        for batch in loader:
            tok, audio, labels, meta = trainer._standardize_batch(batch)
            audio = audio.to(trainer.device, non_blocking=True)
            labels = labels.to(trainer.device, non_blocking=True)
            tok = trainer._to_device_text(tok)

            out = trainer.network(tok, audio, meta=meta)  # <<< pass meta
            logits = out[0] if isinstance(out, (tuple, list)) else out
            preds = torch.argmax(logits, dim=1)
            all_preds.append(preds.cpu())
            all_labels.append(labels.cpu())
    return torch.cat(all_preds), torch.cat(all_labels)

if eval_loader is not None:
    preds, labels = collect_preds(trainer, eval_loader)
    num_classes = cfg.num_classes

    cm = torch.zeros((num_classes, num_classes), dtype=torch.int32)
    for t, p in zip(labels, preds):
        cm[t.long(), p.long()] += 1

    per_class_acc = (cm.diag().float() / cm.sum(dim=1).clamp(min=1).float()).numpy()
    overall_acc = (preds == labels).float().mean().item()

    print("Overall Acc: %.4f" % overall_acc)
    print("Per-class Acc:")
    for i, acc in enumerate(per_class_acc):
        name = str(i)
        try:
            name = id2label[i]
        except Exception:
            pass
        print(f"  {i} ({name}): {acc:.4f}")
    print("Confusion Matrix:\n", cm.numpy())

    try:
        from sklearn.metrics import classification_report
        target_names = [str(i) for i in range(num_classes)]
        try:
            target_names = [id2label[i] for i in range(num_classes)]
        except Exception:
            pass
        print("\nClassification Report:")
        print(classification_report(labels.numpy(), preds.numpy(), target_names=target_names, digits=4))
    except Exception:
        pass
else:
    print("No eval_loader available.")
# Out:
# Overall Acc: 0.4000
# Per-class Acc:
#   0 (angry): 0.0000
#   1 (fear): 0.2000
#   2 (happiness): 0.6000
#   3 (neutral): 0.2000
#   4 (sadness): 0.8333
# Confusion Matrix:
#  [[0 1 2 1 0]
#  [1 1 1 2 0]
#  [0 1 3 1 0]
#  [2 1 0 1 1]
#  [0 1 0 0 5]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        angry     0.0000    0.0000    0.0000         4
#         fear     0.2000    0.2000    0.2000         5
#    happiness     0.5000    0.6000    0.5455         5
#      neutral     0.2000    0.2000    0.2000         5
#      sadness     0.8333    0.8333    0.8333         6
#
#     accuracy                         0.4000        25
#    macro avg     0.3467    0.3667    0.3558        25
# weighted avg     0.3800    0.4000    0.3891        25

# %%
# %%
from pathlib import Path
import numpy as np
import soundfile as sf
import torch
from loading.dataloader import VNEMOSDataset, _clean_text
from configs.base import Config

# Dùng đúng cfg bạn huấn luyện: với Phương án A phải max_audio_sec=None
cfg_check = Config(
    data_root="../output",
    jsonl_dir="",
    sample_rate=16000,
    max_audio_sec=None,     # RẤT QUAN TRỌNG: để None thì dataset không cắt cứng
    text_max_length=64,
    use_length_bucket=True,
)

train_set = VNEMOSDataset(cfg_check, "train")  # hoặc "valid"/"test"

def expected_len_after_resample(item, target_sr: int):
    """Tính số mẫu kỳ vọng sau khi cắt start/end và RESAMPLE về target_sr."""
    wav_path = train_set._resolve_wav(item["wav_path"])
    info = sf.info(str(wav_path))
    orig_sr = info.samplerate
    orig_frames = info.frames
    start = float(item.get("start", 0.0) or 0.0)
    end   = float(item.get("end", 0.0) or 0.0)
    if end and end > 0:
        dur_s = max(0.0, end - start)
    else:
        dur_s = orig_frames / float(orig_sr)
    # sau resample, số mẫu ≈ dur_s * target_sr
    return int(round(dur_s * target_sr))

def audit_audio_full(ds, max_examples=999999, tol_samples=4):
    """
    Kiểm tra L_thực / L_kỳ vọng.
    - tol_samples: dung sai vài sample do làm tròn/resample.
    """
    bad = []
    diffs = []
    for i, it in enumerate(ds.items[:max_examples]):
        exp_len = expected_len_after_resample(it, ds.sample_rate)
        ex = ds[i]  # kích hoạt __getitem__
        act_len = int(ex["audio"].numel())
        diffs.append(act_len - exp_len)
        # nếu act_len < exp_len - tol => có vẻ bị cắt
        if exp_len > 0 and act_len + tol_samples < exp_len:
            bad.append((i, it["wav_path"], exp_len, act_len))
    diffs = np.array(diffs, dtype=np.int64)
    return bad, diffs

bad, diffs = audit_audio_full(train_set)

print(f"[Audio] Tổng mẫu kiểm: {len(train_set.items)}")
print(f"[Audio] Sai khác (act-exp) min/mean/max:", diffs.min(), diffs.mean().round(2), diffs.max())
print(f"[Audio] Số mẫu NGHI BỊ CẮT (act << exp): {len(bad)}")
if bad[:10]:
    print("Ví dụ 5 mẫu đầu NGHI BỊ CẮT:")
    for row in bad[:5]:
        i, path, exp_len, act_len = row
        print(f"  idx={i} | {path} | expected={exp_len} | actual={act_len}")
# Out:
# [Audio] Tổng mẫu kiểm: 200
# [Audio] Sai khác (act-exp) min/mean/max: 0 0.0 0
# [Audio] Số mẫu NGHI BỊ CẮT (act << exp): 0
